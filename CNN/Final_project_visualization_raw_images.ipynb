# %%
import nibabel as nib
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

brain_img = nib.load('Preprocessed_AD%2FADNI_003_S_4142_MR_MT1__GradWarp__N3m_Br_20110910141040514_S121319_I255423.nii')
brain_img_data = brain_img.get_data()
slice_0 = brain_img_data[100, :, :]
slice_1 = brain_img_data[:, 30, :]
slice_2 = brain_img_data[:, :, 16]

img_tf = tf.Variable(brain_img_data)
img_tf = tf.Variable(slice_0)

# %%
brain_img = nib.load('Preprocessed_AD%2FADNI_003_S_4142_MR_MT1__GradWarp__N3m_Br_20110910141040514_S121319_I255423.nii')

# %%
epi_img_data = brain_img.get_data()

# %%
epi_img_data.shape
# Out:
# (196, 256, 256)

# %%
slice_0 = epi_img_data[100, :, :]

# %%
slice_1 = epi_img_data[:, 30, :]
slice_2 = epi_img_data[:, :, 16]

# %%
import matplotlib.pyplot as plt

# %%
def show_slices(slices):
    fig, axes = plt.subplots(1, len(slices))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap="gray", origin="lower")

# %%
show_slices([slice_0, slice_1, slice_2])

# %%
plt.show()
